# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r'C:\Users\Chuck\Desktop\arduino\light_monitor\power.csv')#this creates a dataframe read in by pandas
X = dataset.iloc[:,:].values 
print(dataset.columns)
# Out:
# Index(['currentMillis', 'busvoltage', 'shuntvoltage', 'loadvoltage',
#        'current_ma', 'power_mw', 'mAh'],
#       dtype='object')

# %%
fig=plt.figure()
plt.title('Power Draw')
ax=fig.add_subplot(111,label="1")
ax2=fig.add_subplot(111,label="2", frame_on=False)

#plot 1
ax.plot(X[:,0]/1000, X[:,4], color = 'red')

ax.set_xlabel('Time (s)')
ax.set_ylabel('mA')

ax2.plot(X[:,0]/1000, X[:,6], color = 'blue')
ax2.set_ylabel('mAh')
ax2.set_label_position('right')

'''
plt.plot(X[:,0]/1000, X[:,6], color = 'blue')
plt.title('Power Draw')
plt.xlabel('Time (s)')
plt.ylabel('mA')
'''
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-f5792e8c1326> in <module>
#      12 ax2.plot(X[:,0]/1000, X[:,6], color = 'red')
#      13 ax2.set_ylabel('mAh')
# ---> 14 ax2.set_label_position('right')
#      15
#      16 '''
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_label_position'
